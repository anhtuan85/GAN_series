# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision.transforms as transforms
from torchvision import datasets
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %% [markdown]
# ## Hyperparameter

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
batch_size = 64
lr = 0.0002
num_workers = 0
img_shape = (1, 28, 28)
g_input_dim = 100
num_epochs = 100

# %% [markdown]
# ## MNIST Datasets

# %%
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize([0.5], [0.5])])

# %%
train_data = datasets.MNIST(root= "data", train = True, transform= transform, download= True)

train_loader = torch.utils.data.DataLoader(train_data, batch_size= batch_size, num_workers= num_workers)

# %%
def visualize(dataloader):
    dataiter = iter(dataloader)
    images, labels = dataiter.next()
    images = images / 2 + 0.5  
    images = images.numpy()
    
    #get one image in batch
    img = np.squeeze(images[5])
    fig = plt.figure(figsize = (3,3)) 
    ax = fig.add_subplot(111)
    ax.imshow(img, cmap='gray')

visualize(train_loader)

# %% [markdown]
# ## Define the model

# %% [markdown]
# ### Generator

# %%
class Generator(nn.Module):
    def __init__(self, input_dim, output_dim = 784):
        super(Generator, self).__init__()

        self.fc1 = nn.Linear(input_dim, 256)
        self.fc2 = nn.Linear(256, 512)
        self.fc3 = nn.Linear(512, 1024)
        self.fc4 = nn.Linear(1024, output_dim)
    
        self.drop_out = nn.Dropout(0.3)
    def forward(self, x):
        x = F.leaky_relu(self.fc1(x), 0.2)
        x = self.drop_out(x)

        x = F.leaky_relu(self.fc2(x), 0.2)
        x = self.drop_out(x)

        x = F.leaky_relu(self.fc3(x), 0.2)
        x = self.drop_out(x)

        out = F.tanh(self.fc4(x))
        return out

# %% [markdown]
# ### Discriminator

# %%
class Discriminator(nn.Module):
    def __init__(self, input_dim):
        super(Discriminator, self).__init__()
        self.fc1 = nn.Linear(input_dim, 1024)
        self.fc2 = nn.Linear(1024, 512)
        self.fc3 = nn.Linear(512, 256)
        self.fc4  = nn.Linear(256, 1)

        self.dropout = nn.Dropout(0.3)
    def forward(self, img):
        x = img.view(img.size(0), -1)
        x = F.leaky_relu(self.fc1(x), 0.2)
        x = self.dropout(x)

        x = F.leaky_relu(self.fc2(x), 0.2)
        x = self.dropout(x)

        x = F.leaky_relu(self.fc3(x), 0.2)
        x = self.dropout(x)
        out = self.fc4(x)
        #out = F.sigmoid(self.fc4(x))
        return out

# %%
G = Generator(g_input_dim, output_dim= 784).to(device)
D = Discriminator(input_dim= 784).to(device)

print(G)
print(D)
# Out:
# Generator(
#   (fc1): Linear(in_features=100, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=512, bias=True)
#   (fc3): Linear(in_features=512, out_features=1024, bias=True)
#   (fc4): Linear(in_features=1024, out_features=784, bias=True)
#   (drop_out): Dropout(p=0.3, inplace=False)
# )
# Discriminator(
#   (fc1): Linear(in_features=784, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=512, bias=True)
#   (fc3): Linear(in_features=512, out_features=256, bias=True)
#   (fc4): Linear(in_features=256, out_features=1, bias=True)
#   (dropout): Dropout(p=0.3, inplace=False)
# )

# %% [markdown]
# ## Define Losses and Optimizers

# %%
def real_loss(D_out):
    batch_size = D_out.size(0)
    labels = torch.ones(batch_size).to(device)
    #MSE instead of BCE
    criterion = nn.MSELoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size).to(device) # fake labels = 0
    #MSE insted BCE
    criterion = nn.MSELoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %%
d_optimizer = optim.Adam(D.parameters(), lr)
g_optimizer = optim.Adam(G.parameters(), lr)

# %% [markdown]
# ## Training

# %%
D.train()
G.train()
for epoch in range(num_epochs):
    for i, (real_images, _) in enumerate(train_loader):
        batch_size = real_images.size(0)
        real_images = real_images.to(device)

        #TRAIN DISCRIMINATOR
        d_optimizer.zero_grad()

        #Train with real images
        D_real = D(real_images)
        d_real_loss = real_loss(D_real)

        #Train with fake images
        z = np.random.uniform(-1, 1, size= (batch_size, g_input_dim))
        z = torch.from_numpy(z).float().to(device)
        fake_images = G(z)
        D_fake = D(fake_images)
        d_fake_loss = fake_loss(D_fake)

        #Combine loss
        d_loss = 0.5*(d_real_loss + d_fake_loss)
        d_loss.backward()
        d_optimizer.step()

        #TRAIN GENERATOR
        g_optimizer.zero_grad()

        z = np.random.uniform(-1, 1, size= (batch_size, g_input_dim))
        z = torch.from_numpy(z).float().to(device)
        fake_images = G(z)
        D_fake = D(fake_images)
        g_loss = 0.5* real_loss(D_fake)

        g_loss.backward()
        g_optimizer.step()
    
    print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
        epoch+1, num_epochs, d_loss.item(), g_loss.item()))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1558: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Epoch [    1/  100] | d_loss: 0.0367 | g_loss: 0.7480
# Epoch [    2/  100] | d_loss: 0.0404 | g_loss: 0.5249
# Epoch [    3/  100] | d_loss: 0.0440 | g_loss: 0.3816
# Epoch [    4/  100] | d_loss: 0.0244 | g_loss: 0.3404
# Epoch [    5/  100] | d_loss: 0.0812 | g_loss: 0.3217
# Epoch [    6/  100] | d_loss: 0.0806 | g_loss: 0.2637
# Epoch [    7/  100] | d_loss: 0.0566 | g_loss: 0.4124
# Epoch [    8/  100] | d_loss: 0.0745 | g_loss: 0.4515
# Epoch [    9/  100] | d_loss: 0.0688 | g_loss: 0.3951
# Epoch [   10/  100] | d_loss: 0.1025 | g_loss: 0.2768
# Epoch [   11/  100] | d_loss: 0.1244 | g_loss: 0.3211
# Epoch [   12/  100] | d_loss: 0.1323 | g_loss: 0.1592
# Epoch [   13/  100] | d_loss: 0.1256 | g_loss: 0.2608
# Epoch [   14/  100] | d_loss: 0.1237 | g_loss: 0.3418
# Epoch [   15/  100] | d_loss: 0.1560 | g_loss: 0.2227
# Epoch [   16/  100] | d_loss: 0.1423 | g_loss: 0.2231
# Epoch [   17/  100] | d_loss: 0.1977 | g_loss: 0.2793
# Epoch [   18/  100] | d_loss: 0.1935 | g_loss: 0.2208
# Epoch [   19/  100] | d_loss: 0.1657 | g_loss: 0.1594
# Epoch [   20/  100] | d_loss: 0.1716 | g_loss: 0.2134
# Epoch [   21/  100] | d_loss: 0.1368 | g_loss: 0.2242
# Epoch [   22/  100] | d_loss: 0.1701 | g_loss: 0.2903
# Epoch [   23/  100] | d_loss: 0.1661 | g_loss: 0.1664
# Epoch [   24/  100] | d_loss: 0.1788 | g_loss: 0.2430
# Epoch [   25/  100] | d_loss: 0.2008 | g_loss: 0.1926
# Epoch [   26/  100] | d_loss: 0.1967 | g_loss: 0.1510
# Epoch [   27/  100] | d_loss: 0.1558 | g_loss: 0.2564
# Epoch [   28/  100] | d_loss: 0.1260 | g_loss: 0.1987
# Epoch [   29/  100] | d_loss: 0.1588 | g_loss: 0.2929
# Epoch [   30/  100] | d_loss: 0.1762 | g_loss: 0.1584
# Epoch [   31/  100] | d_loss: 0.1475 | g_loss: 0.2310
# Epoch [   32/  100] | d_loss: 0.1390 | g_loss: 0.2239
# Epoch [   33/  100] | d_loss: 0.1602 | g_loss: 0.2394
# Epoch [   34/  100] | d_loss: 0.1856 | g_loss: 0.2872
# Epoch [   35/  100] | d_loss: 0.2142 | g_loss: 0.2151
# Epoch [   36/  100] | d_loss: 0.1573 | g_loss: 0.1900
# Epoch [   37/  100] | d_loss: 0.1985 | g_loss: 0.1532
# Epoch [   38/  100] | d_loss: 0.1603 | g_loss: 0.1791
# Epoch [   39/  100] | d_loss: 0.1814 | g_loss: 0.1843
# Epoch [   40/  100] | d_loss: 0.1589 | g_loss: 0.2239
# Epoch [   41/  100] | d_loss: 0.1604 | g_loss: 0.2922
# Epoch [   42/  100] | d_loss: 0.1868 | g_loss: 0.1773
# Epoch [   43/  100] | d_loss: 0.1701 | g_loss: 0.2040
# Epoch [   44/  100] | d_loss: 0.1678 | g_loss: 0.1807
# Epoch [   45/  100] | d_loss: 0.2074 | g_loss: 0.1559
# Epoch [   46/  100] | d_loss: 0.1809 | g_loss: 0.2098
# Epoch [   47/  100] | d_loss: 0.1987 | g_loss: 0.2062
# Epoch [   48/  100] | d_loss: 0.1861 | g_loss: 0.1637
# Epoch [   49/  100] | d_loss: 0.1875 | g_loss: 0.1665
# Epoch [   50/  100] | d_loss: 0.2259 | g_loss: 0.2064
# Epoch [   51/  100] | d_loss: 0.1737 | g_loss: 0.1773
# Epoch [   52/  100] | d_loss: 0.1929 | g_loss: 0.1857
# Epoch [   53/  100] | d_loss: 0.1876 | g_loss: 0.1587
# Epoch [   54/  100] | d_loss: 0.1308 | g_loss: 0.1868
# Epoch [   55/  100] | d_loss: 0.1482 | g_loss: 0.1946
# Epoch [   56/  100] | d_loss: 0.1420 | g_loss: 0.2283
# Epoch [   57/  100] | d_loss: 0.1516 | g_loss: 0.2467
# Epoch [   58/  100] | d_loss: 0.1779 | g_loss: 0.2195
# Epoch [   59/  100] | d_loss: 0.1860 | g_loss: 0.2361
# Epoch [   60/  100] | d_loss: 0.1166 | g_loss: 0.2461
# Epoch [   61/  100] | d_loss: 0.1946 | g_loss: 0.1919
# Epoch [   62/  100] | d_loss: 0.1919 | g_loss: 0.1771
# Epoch [   63/  100] | d_loss: 0.1604 | g_loss: 0.2213
# Epoch [   64/  100] | d_loss: 0.1852 | g_loss: 0.2396
# Epoch [   65/  100] | d_loss: 0.1758 | g_loss: 0.2105
# Epoch [   66/  100] | d_loss: 0.1875 | g_loss: 0.1953
# Epoch [   67/  100] | d_loss: 0.1578 | g_loss: 0.1659
# Epoch [   68/  100] | d_loss: 0.1735 | g_loss: 0.1801
# Epoch [   69/  100] | d_loss: 0.2050 | g_loss: 0.1916
# Epoch [   70/  100] | d_loss: 0.1009 | g_loss: 0.2418
# Epoch [   71/  100] | d_loss: 0.1836 | g_loss: 0.1589
# Epoch [   72/  100] | d_loss: 0.1515 | g_loss: 0.2835
# Epoch [   73/  100] | d_loss: 0.1834 | g_loss: 0.1807
# Epoch [   74/  100] | d_loss: 0.2033 | g_loss: 0.2159
# Epoch [   75/  100] | d_loss: 0.1225 | g_loss: 0.2592
# Epoch [   76/  100] | d_loss: 0.2076 | g_loss: 0.1467
# Epoch [   77/  100] | d_loss: 0.1629 | g_loss: 0.1664
# Epoch [   78/  100] | d_loss: 0.1693 | g_loss: 0.1957
# Epoch [   79/  100] | d_loss: 0.1477 | g_loss: 0.2207
# Epoch [   80/  100] | d_loss: 0.1548 | g_loss: 0.2072
# Epoch [   81/  100] | d_loss: 0.1679 | g_loss: 0.2305
# Epoch [   82/  100] | d_loss: 0.1190 | g_loss: 0.1796
# Epoch [   83/  100] | d_loss: 0.1922 | g_loss: 0.2204
# Epoch [   84/  100] | d_loss: 0.1555 | g_loss: 0.1907
# Epoch [   85/  100] | d_loss: 0.1792 | g_loss: 0.1684
# Epoch [   86/  100] | d_loss: 0.1850 | g_loss: 0.1677
# Epoch [   87/  100] | d_loss: 0.1734 | g_loss: 0.1630
# Epoch [   88/  100] | d_loss: 0.1679 | g_loss: 0.2230
# Epoch [   89/  100] | d_loss: 0.1753 | g_loss: 0.2268
# Epoch [   90/  100] | d_loss: 0.2043 | g_loss: 0.1972
# Epoch [   91/  100] | d_loss: 0.1672 | g_loss: 0.1860
# Epoch [   92/  100] | d_loss: 0.1678 | g_loss: 0.1617
# Epoch [   93/  100] | d_loss: 0.1593 | g_loss: 0.1904
# Epoch [   94/  100] | d_loss: 0.1878 | g_loss: 0.1750
# Epoch [   95/  100] | d_loss: 0.1988 | g_loss: 0.2106
# Epoch [   96/  100] | d_loss: 0.1952 | g_loss: 0.2365
# Epoch [   97/  100] | d_loss: 0.1547 | g_loss: 0.2213
# Epoch [   98/  100] | d_loss: 0.1855 | g_loss: 0.1713
# Epoch [   99/  100] | d_loss: 0.1800 | g_loss: 0.1769
# Epoch [  100/  100] | d_loss: 0.1764 | g_loss: 0.2062

# %% [markdown]
# ## Evaluation

# %%
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(7,7), nrows=4, ncols=4, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach()
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((28,28)).to("cpu"), cmap='Greys_r')

# %%
# randomly generated, new latent vectors
sample_size=20
rand_z = np.random.uniform(-1, 1, size=(sample_size, g_input_dim))
rand_z = torch.from_numpy(rand_z).float().to(device)

G.eval() # eval mode
# generated samples
rand_images = G(rand_z)
view_samples(0, [rand_images])
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:1558: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
